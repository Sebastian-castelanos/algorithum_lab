# %% [markdown]
# <a href="https://colab.research.google.com/github/Sebastian-castelanos/algorithum_lab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def modifed_dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
import sys

def modified_dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    distances[start] = 0
    visited = []

    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')
        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)
        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances
graph_2 = {}
n1 = int(input("Enter number of nodes: "))
for i in range(n1):
    node = input("Enter node name: ")
    neighbors = {}
    n2 = int(input(f"Enter number of neighbors for {node}: "))
    for j in range(n2):
        neighbor = input("Enter neighbor name: ")
        weight = int(input("Enter weight: "))
        neighbors[neighbor] = weight
    graph_2[node] = neighbors

graph_2['E'] = {'A': 2, 'D': 1}
graph_2['F'] = {'B': 3}
print("\nGraph Structure:", graph_2)
source = input("\nEnter source node: ")

if source in graph_2:
    result = modified_dijkstra(graph_2, source)
    print(f"\nShortest distances from {source}:")
    for node, distance in result.items():
        print(f"To {node} = {distance}")
else:
    print("Source node not in graph.")
# Out:
# Enter number of nodes: 3
# Enter node name: a
# Enter number of neighbors for a: 2
# Enter neighbor name: b
# Enter weight: 3
# Enter neighbor name: c
# Enter weight: 8
# Enter node name: b
# Enter number of neighbors for b: 1
# Enter neighbor name: a
# Enter weight: 3
# Enter node name: c
# Enter number of neighbors for c: 1
# Enter neighbor name: a
# Enter weight: 8
#
# Graph Structure: {'a': {'b': 3, 'c': 8}, 'b': {'a': 3}, 'c': {'a': 8}, 'E': {'A': 2, 'D': 1}, 'F': {'B': 3}}
#
# Enter source node: a
#
# Shortest distances from a:
# To a = 0
# To b = 3
# To c = 8
# To E = inf
# To F = inf

# %%
graph_2 = {}
n1 = int(input(" NO.of nodes: "))
for i in range(n1):
    node = input("node name: ")
    neighbors = {}
    n2 = int(input(f"no. of neighbors for {node}: "))
    for j in range(n2):
        neighbor = input("neighbor name: ")
        weight = int(input("weight: "))
        neighbors[neighbor] = weight
    graph_2[node] = neighbors



def modified_dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items:
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

result = modifed_dijkstra(graph, 'A')
for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3868/1859157098.py in <cell line: 0>()
#       1 graph_2 = {}
# ----> 2 n1 = int(input(" NO.of nodes: "))
#       3 for i in range(n1):
#       4     node = input("node name: ")
#       5     neighbors = {}
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3868/2014396501.py in <cell line: 0>()
#      25     return distances
#      26 graph_2 = {}
# ---> 27 n1 = int(input("Enter number of nodes: "))
#      28 for i in range(n1):
#      29     node = input("Enter node name: ")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
